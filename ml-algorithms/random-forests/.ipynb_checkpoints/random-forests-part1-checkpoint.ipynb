# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

# %%
X,y=make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0  0.595877  3.006537 -2.109994  1.227045 -1.478891       1
# 1  0.024489  0.590091 -0.313586  0.973815 -1.274180       1
# 2  2.894173 -0.290396 -2.875996  0.978672  0.277528       1
# 3  0.971821  0.504104  0.616823  1.425566 -1.210308       0
# 4  1.312231  0.228076  0.936021  0.956578 -1.354258       0

# %%
# function for row sampling

def sample_rows(df,percent):
    return df.sample(int(percent*df.shape[0]),replace=True)

# %%
import random
# function for feature sampling
def sample_features(df,percent):
    cols = random.sample(df.columns.tolist()[:-1],int(percent*(df.shape[1]-1)))
    new_df = df[cols]
    new_df['target'] = df['target']
    return new_df

# %%
# function for combined sampling

def combined_sampling(df,row_percent,col_percent):
    new_df = sample_rows(df,row_percent)
    return sample_features(new_df,col_percent)

# %% [markdown]
# ### Working of row sampling

# %% [markdown]
# ##### Creating different datasets,to give it to different trees.

# %%
df1=sample_rows(df,0.1)

# %%
df2=sample_rows(df,0.1)

# %%
df3=sample_rows(df,0.1)

# %%
df1.shape,df2.shape,df3.shape
# Out:
# ((10, 6), (10, 6), (10, 6))

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,0:5],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:5],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:5],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf1)
# Out:
# [Text(0.6, 0.8333333333333334, 'x[2] <= 0.9\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.4, 0.5, 'x[3] <= 0.216\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.2, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6, 0.16666666666666666, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]')]

# %%
plot_tree(clf2)
# Out:
# [Text(0.5, 0.5, 'gini = 0.0\nsamples = 10\nvalue = 10.0')]

# %%
plot_tree(clf3)
# Out:
# [Text(0.6, 0.8333333333333334, 'x[2] <= -0.087\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.4, 0.5, 'x[4] <= -1.527\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.2, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6, 0.16666666666666666, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.8, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]')]

# %% [markdown]
# ##### Now, recording the prediction from each decision tree model

# %%
clf1.predict(np.array([0.595877,3.006537,-2.109994,1.227045,-1.478891]).reshape(1,5))
# Out:
# C:\Users\bagwe\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf2.predict(np.array([0.595877,3.006537,-2.109994,1.227045,-1.478891]).reshape(1,5))
# Out:
# C:\Users\bagwe\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
clf3.predict(np.array([0.595877,3.006537,-2.109994,1.227045,-1.478891]).reshape(1,5))
# Out:
# C:\Users\bagwe\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %% [markdown]
# ### Working of column sampling

# %%
df1=sample_features(df,0.8)
# Out:
# C:\Users\bagwe\AppData\Local\Temp\ipykernel_14936\2680782937.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
df2=sample_features(df,0.8)
# Out:
# C:\Users\bagwe\AppData\Local\Temp\ipykernel_14936\2680782937.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
df3=sample_features(df,0.8)
# Out:
# C:\Users\bagwe\AppData\Local\Temp\ipykernel_14936\2680782937.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,0:4],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:4],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:4],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
plot_tree(clf1)
# Out:
# [Text(0.5, 0.9285714285714286, 'x[0] <= -0.23\ngini = 0.5\nsamples = 100\nvalue = [50, 50]'),
#  Text(0.25, 0.7857142857142857, 'x[1] <= 1.777\ngini = 0.305\nsamples = 48\nvalue = [9, 39]'),
#  Text(0.125, 0.6428571428571429, 'x[2] <= 0.029\ngini = 0.071\nsamples = 27\nvalue = [1, 26]'),
#  Text(0.0625, 0.5, 'gini = 0.0\nsamples = 26\nvalue = [0, 26]'),
#  Text(0.1875, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.375, 0.6428571428571429, 'x[2] <= -1.042\ngini = 0.472\nsamples = 21\nvalue = [8, 13]'),
#  Text(0.3125, 0.5, 'x[0] <= -2.966\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.25, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.375, 0.35714285714285715, 'x[3] <= -0.729\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.3125, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4375, 0.21428571428571427, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
# ...

# %%
plot_tree(clf2)
# Out:
# [Text(0.55, 0.95, 'x[0] <= -0.23\ngini = 0.5\nsamples = 100\nvalue = [50, 50]'),
#  Text(0.3, 0.85, 'x[1] <= -0.413\ngini = 0.305\nsamples = 48\nvalue = [9, 39]'),
#  Text(0.25, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.35, 0.75, 'x[2] <= 0.962\ngini = 0.282\nsamples = 47\nvalue = [8, 39]'),
#  Text(0.25, 0.65, 'x[1] <= 2.627\ngini = 0.375\nsamples = 28\nvalue = [7, 21]'),
#  Text(0.2, 0.55, 'x[2] <= 0.68\ngini = 0.311\nsamples = 26\nvalue = [5, 21]'),
#  Text(0.15, 0.45, 'x[1] <= 1.098\ngini = 0.219\nsamples = 24\nvalue = [3, 21]'),
#  Text(0.1, 0.35, 'x[1] <= 0.772\ngini = 0.355\nsamples = 13\nvalue = [3, 10]'),
#  Text(0.05, 0.25, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.15, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.2, 0.35, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.25, 0.45, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3, 0.55, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
# ...

# %%
plot_tree(clf3)
# Out:
# [Text(0.48214285714285715, 0.9444444444444444, 'x[2] <= -0.797\ngini = 0.5\nsamples = 100\nvalue = [50, 50]'),
#  Text(0.3392857142857143, 0.8333333333333334, 'x[1] <= 4.221\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.26785714285714285, 0.7222222222222222, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.4107142857142857, 0.7222222222222222, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.625, 0.8333333333333334, 'x[2] <= 2.919\ngini = 0.498\nsamples = 92\nvalue = [49, 43]'),
#  Text(0.5535714285714286, 0.7222222222222222, 'x[2] <= 1.755\ngini = 0.494\nsamples = 88\nvalue = [49, 39]'),
#  Text(0.32142857142857145, 0.6111111111111112, 'x[1] <= 0.311\ngini = 0.5\nsamples = 71\nvalue = [35, 36]'),
#  Text(0.14285714285714285, 0.5, 'x[3] <= -0.545\ngini = 0.198\nsamples = 18\nvalue = [2, 16]'),
#  Text(0.07142857142857142, 0.3888888888888889, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
# ...

# %% [markdown]
# ##### Checking which dataset got which column

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['col3', 'col1', 'col5', 'col4', 'target'], dtype='object')
# Index(['col3', 'col2', 'col4', 'col5', 'target'], dtype='object')
# Index(['col2', 'col1', 'col4', 'col5', 'target'], dtype='object')

# %%
df3
# Out:
#         col2      col1      col4      col5  target
# 0   3.006537  0.595877  1.227045 -1.478891       1
# 1   0.590091  0.024489  0.973815 -1.274180       1
# 2  -0.290396  2.894173  0.978672  0.277528       1
# 3   0.504104  0.971821  1.425566 -1.210308       0
# 4   0.228076  1.312231  0.956578 -1.354258       0
# ..       ...       ...       ...       ...     ...
# 95  0.195264  1.507579  0.404075 -0.905047       1
# 96  0.925976  2.354243  0.571253 -1.635587       0
# 97  1.400262  3.751912  2.549861  2.517884       1
# 98  1.201156  0.327996  0.771771  0.313857       0
# 99  1.714126 -0.422470  1.756110  0.732292       0
#
# [100 rows x 5 columns]

# %%
clf1.predict(np.array([3.006537,0.595877,1.227045,-1.478891]).reshape(1,4))
# Out:
# C:\Users\bagwe\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf2.predict(np.array([3.006537,0.595877,1.227045,-1.478891]).reshape(1,4))
# Out:
# C:\Users\bagwe\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf3.predict(np.array([3.006537,0.595877,1.227045,-1.478891]).reshape(1,4))
# Out:
# C:\Users\bagwe\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %% [markdown]
# ### Working of Combined Sampling

# %%
df1 = combined_sampling(df,0.5,0.5)
# Out:
# C:\Users\bagwe\AppData\Local\Temp\ipykernel_14936\2680782937.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
df2 = combined_sampling(df,0.5,0.5)
# Out:
# C:\Users\bagwe\AppData\Local\Temp\ipykernel_14936\2680782937.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
df3 = combined_sampling(df,0.5,0.5)
# Out:
# C:\Users\bagwe\AppData\Local\Temp\ipykernel_14936\2680782937.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['col5', 'col3', 'target'], dtype='object')
# Index(['col3', 'col2', 'target'], dtype='object')
# Index(['col1', 'col4', 'target'], dtype='object')

# %%
df3
# Out:
#         col1      col4  target
# 71  2.481164  0.649128       1
# 91 -0.987600  0.389002       1
# 81 -1.542211  0.914917       1
# 54  0.830125  1.462075       0
# 69 -1.138195  1.313810       0
# 96  2.354243  0.571253       0
# 11  2.999886 -0.609080       0
# 25  1.402900 -0.013641       0
# 86  0.749880  1.284067       1
# 97  3.751912  2.549861       1
# 37  1.891778  0.949813       0
# 79  0.995227  1.128623       0
# 78  0.435076  0.727180       0
# 21  2.891967  3.437279       1
# 69 -1.138195  1.313810       0
# 91 -0.987600  0.389002       1
# 36  2.679118  0.599606       1
# 92  1.615712  0.478688       0
# 45 -1.364624  2.037063       0
# 87  0.989139  1.284056       1
# 33  1.838642 -0.276299       0
# 93  0.665840  1.753725       1
# 89 -0.526584  0.339250       0
# 38  0.108418  2.031351       0
# 68  1.714948  1.262555       1
# 85 -0.080002 -0.072540       1
# 2   2.894173  0.978672       1
# 90  0.289947  0.670948       1
# 29  2.166641  0.724994       1
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,0:2],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:2],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:2],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
plot_tree(clf1)
# Out:
# [Text(0.6363636363636364, 0.95, 'x[1] <= 1.197\ngini = 0.471\nsamples = 50\nvalue = [19, 31]'),
#  Text(0.5454545454545454, 0.85, 'x[0] <= -1.083\ngini = 0.349\nsamples = 40\nvalue = [9, 31]'),
#  Text(0.36363636363636365, 0.75, 'x[1] <= -1.992\ngini = 0.426\nsamples = 26\nvalue = [8, 18]'),
#  Text(0.2727272727272727, 0.65, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.45454545454545453, 0.65, 'x[1] <= 0.447\ngini = 0.48\nsamples = 20\nvalue = [8, 12]'),
#  Text(0.36363636363636365, 0.55, 'x[1] <= -0.164\ngini = 0.498\nsamples = 15\nvalue = [8, 7]'),
#  Text(0.2727272727272727, 0.45, 'x[1] <= -0.542\ngini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(0.18181818181818182, 0.35, 'x[0] <= -3.331\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.09090909090909091, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2727272727272727, 0.25, 'x[0] <= -1.442\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
# ...

# %%
plot_tree(clf2)
# Out:
# [Text(0.5588235294117647, 0.9285714285714286, 'x[0] <= -0.247\ngini = 0.5\nsamples = 50\nvalue = [25, 25]'),
#  Text(0.23529411764705882, 0.7857142857142857, 'x[0] <= -1.579\ngini = 0.355\nsamples = 26\nvalue = [6, 20]'),
#  Text(0.11764705882352941, 0.6428571428571429, 'x[1] <= -0.045\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.058823529411764705, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.17647058823529413, 0.5, 'x[1] <= 1.071\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.11764705882352941, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.23529411764705882, 0.35714285714285715, 'x[1] <= 2.868\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.17647058823529413, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.29411764705882354, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
# ...

# %%
plot_tree(clf3)
# Out:
# [Text(0.5921052631578947, 0.9285714285714286, 'x[1] <= 1.299\ngini = 0.471\nsamples = 50\nvalue = [19, 31]'),
#  Text(0.2894736842105263, 0.7857142857142857, 'x[0] <= 0.992\ngini = 0.394\nsamples = 37\nvalue = [10, 27]'),
#  Text(0.10526315789473684, 0.6428571428571429, 'x[0] <= -0.583\ngini = 0.188\nsamples = 19\nvalue = [2, 17]'),
#  Text(0.05263157894736842, 0.5, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.15789473684210525, 0.5, 'x[0] <= -0.343\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.10526315789473684, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.21052631578947367, 0.35714285714285715, 'x[1] <= 0.865\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.15789473684210525, 0.21428571428571427, 'x[1] <= 0.699\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.10526315789473684, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
# ...

# %%
clf1.predict(np.array([2.481164	,0.649128]).reshape(1,2))
# Out:
# C:\Users\bagwe\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf2.predict(np.array([2.481164	,0.649128]).reshape(1,2))
# Out:
# C:\Users\bagwe\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
clf3.predict(np.array([2.481164	,0.649128]).reshape(1,2))
# Out:
# C:\Users\bagwe\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])
