# %% [markdown]
# ##### Missing values can be handled in two ways :- 1) Removing the entire row  and 2) imputing the missing value.Imputing is further divided into two parts i.e univariate and multivariate.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimg

# %%
img=pltimg.imread('missing-values-methods.png')

# %%
plt.imshow(img)

# %% [markdown]
# ##### Now ,we will learn first type i.e to remove missing values.

# %% [markdown]
# ##### CCA means complete case analysis is the process in which we remove the observations for which value of col is missing.CCA is mostly applied when the values that are missing are  randomly distributed.One of the biggest disadvantage of this technique is that when our model is at production ,it doesnt know how to handle missing data.This technique is only used when we have 5% of missing data.
